# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

def scrape(front_url, back_url='' ,num=[], to_file='out.csv'):
#'''
#    front_url (str): url of website to be scraped. Starts with 'https://'.
#    back_url (str, optional): url trailing the page/results count.
#    num (list of int, optional): list of integers for page/results count. E.g. [100,200,300] or [0,1,2,3].
#    to_file (str,optional): the output csv will be saved to this file name.
#'''

    # Autotrader, used sedans
    cars=[]
    prices=[]
    mileages=[]

    # create list of urls to be loped through
    if num == [] and back_url == '':
        url_list = [front_url]
    else:
        url_list = ["{}{}{}".format(front_url,str(page),back_url) for page in num]

    # psuedo headers for the psuedo browser access
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}

    for url in url_list:
        response = requests.get(url, timeout=5, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # the following is very specific to the website
        for a in soup.findAll('div', attrs={'class':'newSRPDesign'}):
            # add any interested attributes here
            name=a.find('span', attrs={'itemprop':'itemOffered'})
            price=a.find('span', attrs={'class':'price-amount'})
            mileage=a.find('div', attrs={'class':'kms'})
            print(mileage)
            cars.append(name.text.strip())
            prices.append(price.text)
            mileages.append(mileage.text.strip())

    # save our scraped data
    df = pd.DataFrame({'Cars':cars,'Price':prices,'Mileage':mileages}) 
    df.to_csv(to_file, index=False, encoding='utf-8')
    
    print('Scrape successful!')
    return True


#if '__name__' == '__main__':
    
    #backup front page
base_url = 'https://www.autotrader.ca/cars/on/toronto/?rcp=100&rcs=0&srt=3&prx=50&prv=Ontario&loc=M5S%202P9&body=Sedan&hprc=True&wcp=True&sts=Used&adtype=Private&showcpo=1&scpty=5%20seats&inMarket=advancedSearch'
front_url = 'https://www.autotrader.ca/cars/on/toronto/?rcp=100&rcs='
back_url = '&srt=3&prx=50&prv=Ontario&loc=M5S%202P9&body=Sedan&hprc=True&wcp=True&sts=Used&adtype=Private&showcpo=1&scpty=5%20seats&inMarket=advancedSearch' 
    
    #the search contains 15 pages
num = np.arange(3)*100
    
scrape(front_url,back_url,num,to_file='autotrader.csv')
# Out:
# /opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# <div class="kms">
# <b>Mileage</b> 21,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 87,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 27,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 99 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 89,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 165,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 152,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 269,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 110,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 13,998 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 10,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 41,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 44,600 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 37,800 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 45,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 134,329 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 12,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 79,600 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 12,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 62,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 19,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 57,574 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 50,032 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 23,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 25,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 34,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 28,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 51,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 27,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 58,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 35,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 6,100 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 25,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 15,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 48,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 67,583 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 63,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 84,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 5,100 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 35,212 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 30,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 67,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 88,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 52,200 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 35,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 158,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 22,300 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 32,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 45,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 49,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 36,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 44,026 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 83,433 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 83,953 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 86,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 52,700 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 47,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 55,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 65,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 56,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 65,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 105,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 55,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 97,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 90,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 39,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 33,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 84,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 57,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 42,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 46,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 70,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 65,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 94,211 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 17,900 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 24,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 88,400 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 67,101 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 58,204 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 7,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 44,868 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 80,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 58,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 35,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 59,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 8,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 74,800 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 46,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 17,900 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 44,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 36,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 96,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 151,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 65,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 66,531 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 29,700 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 21,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 156,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 21,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 139,968 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 89,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 22,400 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 105,600 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 89,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 165,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 152,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 269,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 97,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 83,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 128,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 71,999 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 101,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 112,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 58,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 75,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 52,900 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 7,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,801 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 105,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 30,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 57,400 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 75,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 36,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 55,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 100,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 54,800 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 104,228 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 114,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 93,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 110,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 48,078 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 42,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 75,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 74,689 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 24,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 148,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 281,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 126,013 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 61,608 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 85,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 90,486 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 71,800 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 76,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 130,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 66,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,112 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 79,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 73,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 17,300 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 76,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 49,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 30,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 75,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 78,416 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 23,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 27,700 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 26,952 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 55,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 100,324 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 4,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 69,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 154,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 159,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 145,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 58,350 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 29,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 111,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 13,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 32,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 106,175 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 142,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 100,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 9,800 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 155,552 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 31,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 126,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 138,200 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 110,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 54,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 55,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 179,300 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 126,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 138,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 54,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 24,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 44,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 45,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 36,300 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 78,400 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 108,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 78,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 100,692 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 87,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 82,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 54,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 62,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,419 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 38,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 119,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 53,668 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 75,713 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 111,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 79,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 47,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 57,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 139,968 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 140,400 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 45,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 215,657 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 45,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 159,900 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 128,317 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 110,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 84,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 139,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 195 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 106,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 40,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 45,797 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 44,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 200,340 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 93,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 36,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 128,300 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 58,560 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 63,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 33,250 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 130,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 130,319 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 173,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 140 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 138,200 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 128,436 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 56,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 136,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 138,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 146,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 74,671 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 64,804 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 125,940 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 80,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 72,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 201,600 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 88,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 87,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 30,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 174,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 36,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 115,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 99,950 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 52,963 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 34,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 25,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 76,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 124,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 99,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 99,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 55,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 57,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 136,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 146,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 65,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 94,547 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 17,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 97,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 88,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 53,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 34,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 93,800 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 71,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 72,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 59,953 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 57,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 100,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 44,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 76,495 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 76,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 135,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 85,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 49,600 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 70,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 61,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 60,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 122,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 52,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 105,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 108,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 48,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 156,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 20,220 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 32,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 132,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 52,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 136,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 100,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 69,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 76,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 114,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 17,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 129,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 113,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 89,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 72,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 58,280 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 38,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 71,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 176,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 135,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 74,000 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 59,500 km
#                                 </div>
# <div class="kms">
# <b>Mileage</b> 56,000 km
#                                 </div>
# Scrape successful!
# True
